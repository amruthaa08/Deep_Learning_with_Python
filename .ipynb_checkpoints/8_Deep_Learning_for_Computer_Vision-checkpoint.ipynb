# %% [markdown]
# # 8.1 Classifying Mnist using a Convnet

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
# creating model (functional API)
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters = 32, kernel_size = 3, activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size = 2)(x)
x = layers.Conv2D(filters = 64, kernel_size = 3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size = 2)(x)
x = layers.Conv2D(filters = 128, kernel_size = 3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs = outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 128)         73856
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 10)                11530
#
# =================================================================
# Total params: 104,202
# Trainable params: 104,202
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fitting model

from tensorflow.keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype("float32") / 255
model.compile(optimizer="rmsprop",
            loss="sparse_categorical_crossentropy",
            metrics=["accuracy"])
model.fit(train_images, train_labels, epochs=5, batch_size=64)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step
# Epoch 1/5
# 938/938 [==============================] - 14s 4ms/step - loss: 0.1641 - accuracy: 0.9494
# Epoch 2/5
# 938/938 [==============================] - 4s 5ms/step - loss: 0.0446 - accuracy: 0.9863
# Epoch 3/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0318 - accuracy: 0.9904
# Epoch 4/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0240 - accuracy: 0.9926
# Epoch 5/5
# 938/938 [==============================] - 5s 5ms/step - loss: 0.0191 - accuracy: 0.9943

# %%
# evaluation
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0265 - accuracy: 0.9919
# Test accuracy: 0.992

# %% [markdown]
# # 8.2 Training a covnet from scratch on a small dataset
# Only code for reference, don't run the code as it's too much for the CPU to handle

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# works only on colab
# !kaggle competitions download -c dogs-vs-cats
# Out:
# Downloading dogs-vs-cats.zip to /content
# 100% 812M/812M [00:35<00:00, 25.8MB/s]
# 100% 812M/812M [00:35<00:00, 24.0MB/s]

# %%
# for colab again
# !unzip -qq dogs-vs-cats.zip
# !unzip -qq train.zip

# %%
# splitting data into required directories
import os, shutil, pathlib
original_dir = pathlib.Path("train")
new_base_dir = pathlib.Path("cats_vs_dogs_small")

def make_subset(subset_name, start_index, end_index):
    for category in ("cat", "dog"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname, dst=dir / fname)

make_subset("train", start_index=0, end_index=1000)
make_subset("validation", start_index=1000, end_index=1500)
make_subset("test", start_index=1500, end_index=2500)

# %%
# building the model
inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(32, (3, 3,), activation="relu")(x)
x = layers.MaxPooling2D(2, 2)(x)
x = layers.Conv2D(64, (3, 3,), activation="relu")(x)
x = layers.MaxPooling2D(2, 2)(x)
x = layers.Conv2D(128, (3, 3,), activation="relu")(x)
x = layers.MaxPooling2D(2, 2)(x)
x = layers.Conv2D(256, (3, 3,), activation="relu")(x)
x = layers.MaxPooling2D(2, 2)(x)
x = layers.Conv2D(256, (3, 3,), activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 178, 178, 32)      896
#
#  max_pooling2d_2 (MaxPooling  (None, 89, 89, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_4 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 18, 18, 256)       295168
#
#  max_pooling2d_5 (MaxPooling  (None, 9, 9, 256)        0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 7, 7, 256)         590080
#
#  flatten_1 (Flatten)         (None, 12544)             0
#
#  dense_1 (Dense)             (None, 1)                 12545
#
# =================================================================
# Total params: 991,041
# Trainable params: 991,041
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="binary_crossentropy",
    optimizer="rmsprop",
    metrics=["accuracy"])

# %%
# data preprocessing
from tensorflow.keras.utils import image_dataset_from_directory
train_dataset = image_dataset_from_directory(
                new_base_dir / "train",
                image_size=(180, 180),
                batch_size=32)
validation_dataset = image_dataset_from_directory(
                new_base_dir / "validation",
                image_size=(180, 180),
                batch_size=32)
test_dataset = image_dataset_from_directory(
                new_base_dir / "test",
                image_size=(180, 180),
                batch_size=32)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %%
# don't run mahn
callbacks = [
        keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss")
]

history = model.fit(
        train_dataset,
        epochs=30,
        validation_data=validation_dataset,
        callbacks=callbacks)
# Out:
# Epoch 1/30
# 63/63 [==============================] - 7s 71ms/step - loss: 0.7010 - accuracy: 0.5290 - val_loss: 0.6922 - val_accuracy: 0.5010
# Epoch 2/30
# 63/63 [==============================] - 5s 80ms/step - loss: 0.6975 - accuracy: 0.5535 - val_loss: 0.6808 - val_accuracy: 0.5360
# Epoch 3/30
# 63/63 [==============================] - 4s 62ms/step - loss: 0.6899 - accuracy: 0.5785 - val_loss: 0.6519 - val_accuracy: 0.6470
# Epoch 4/30
# 63/63 [==============================] - 5s 69ms/step - loss: 0.6461 - accuracy: 0.6345 - val_loss: 0.6237 - val_accuracy: 0.6500
# Epoch 5/30
# 63/63 [==============================] - 5s 65ms/step - loss: 0.6084 - accuracy: 0.6670 - val_loss: 0.6556 - val_accuracy: 0.6160
# Epoch 6/30
# 63/63 [==============================] - 4s 59ms/step - loss: 0.5781 - accuracy: 0.7010 - val_loss: 0.7468 - val_accuracy: 0.6250
# Epoch 7/30
# 63/63 [==============================] - 6s 86ms/step - loss: 0.5368 - accuracy: 0.7280 - val_loss: 0.5591 - val_accuracy: 0.7080
# Epoch 8/30
# 63/63 [==============================] - 4s 61ms/step - loss: 0.5065 - accuracy: 0.7595 - val_loss: 0.5889 - val_accuracy: 0.7020
# Epoch 9/30
# 63/63 [==============================] - 4s 61ms/step - loss: 0.4629 - accuracy: 0.7835 - val_loss: 0.5846 - val_accuracy: 0.6930
# Epoch 10/30
# 63/63 [==============================] - 5s 78ms/step - loss: 0.4097 - accuracy: 0.8030 - val_loss: 0.5730 - val_accuracy: 0.7290
# Epoch 11/30
# 63/63 [==============================] - 4s 62ms/step - loss: 0.3600 - accuracy: 0.8445 - val_loss: 0.5687 - val_accuracy: 0.7480
# Epoch 12/30
# 63/63 [==============================] - 4s 62ms/step - loss: 0.2899 - accuracy: 0.8785 - val_loss: 0.6362 - val_accuracy: 0.7650
# Epoch 13/30
# 63/63 [==============================] - 5s 78ms/step - loss: 0.2450 - accuracy: 0.8950 - val_loss: 0.7296 - val_accuracy: 0.7490
# Epoch 14/30
# 63/63 [==============================] - 4s 59ms/step - loss: 0.2115 - accuracy: 0.9195 - val_loss: 0.7008 - val_accuracy: 0.7600
# Epoch 15/30
# 63/63 [==============================] - 5s 69ms/step - loss: 0.1522 - accuracy: 0.9430 - val_loss: 0.9468 - val_accuracy: 0.7440
# Epoch 16/30
# 63/63 [==============================] - 5s 69ms/step - loss: 0.1344 - accuracy: 0.9505 - val_loss: 1.0933 - val_accuracy: 0.7270
# Epoch 17/30
# 63/63 [==============================] - 4s 62ms/step - loss: 0.1105 - accuracy: 0.9630 - val_loss: 1.4277 - val_accuracy: 0.7210
# Epoch 18/30
# 63/63 [==============================] - 6s 93ms/step - loss: 0.1019 - accuracy: 0.9635 - val_loss: 1.1624 - val_accuracy: 0.7600
# Epoch 19/30
# 63/63 [==============================] - 4s 61ms/step - loss: 0.0781 - accuracy: 0.9750 - val_loss: 1.1946 - val_accuracy: 0.7580
# Epoch 20/30
# 63/63 [==============================] - 5s 73ms/step - loss: 0.0647 - accuracy: 0.9815 - val_loss: 1.4229 - val_accuracy: 0.7250
# Epoch 21/30
# 63/63 [==============================] - 4s 63ms/step - loss: 0.0731 - accuracy: 0.9790 - val_loss: 1.4083 - val_accuracy: 0.7390
# Epoch 22/30
# 63/63 [==============================] - 6s 88ms/step - loss: 0.0445 - accuracy: 0.9830 - val_loss: 1.4592 - val_accuracy: 0.7390
# Epoch 23/30
# 63/63 [==============================] - 4s 61ms/step - loss: 0.0286 - accuracy: 0.9895 - val_loss: 1.5819 - val_accuracy: 0.7500
# Epoch 24/30
# 63/63 [==============================] - 4s 65ms/step - loss: 0.0508 - accuracy: 0.9815 - val_loss: 1.6979 - val_accuracy: 0.7340
# Epoch 25/30
# 63/63 [==============================] - 6s 94ms/step - loss: 0.0825 - accuracy: 0.9790 - val_loss: 1.5848 - val_accuracy: 0.7480
# Epoch 26/30
# 63/63 [==============================] - 4s 68ms/step - loss: 0.0526 - accuracy: 0.9835 - val_loss: 1.6645 - val_accuracy: 0.7540
# Epoch 27/30
# 63/63 [==============================] - 7s 105ms/step - loss: 0.0303 - accuracy: 0.9915 - val_loss: 1.8211 - val_accuracy: 0.7420
# Epoch 28/30
# 63/63 [==============================] - 4s 65ms/step - loss: 0.0096 - accuracy: 0.9975 - val_loss: 2.1948 - val_accuracy: 0.7470
# Epoch 29/30
# 63/63 [==============================] - 4s 61ms/step - loss: 0.0610 - accuracy: 0.9850 - val_loss: 1.7600 - val_accuracy: 0.7530
# Epoch 30/30
# 63/63 [==============================] - 4s 60ms/step - loss: 0.0350 - accuracy: 0.9890 - val_loss: 2.4832 - val_accuracy: 0.7370

# %%
test_model = keras.models.load_model("convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 [==============================] - 3s 33ms/step - loss: 0.5730 - accuracy: 0.7065
# Test accuracy: 0.706

# %%
# seeing loss and accuracy plots
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# ## Adding data augmentation
#
# The above procedure resulted in overfitting, so let's use data augmentation to improve ovrefitting

# %%
# create a data augmentation stage
# a sequential model containing multiple data augmentation layers

data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
])

# %%
# ignoring warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# displaying some randomly augmneted training images
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i+1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
# also add dropout to the existing model to further get rid of overfitting
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
            optimizer="rmsprop",
            metrics=["accuracy"])
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
# training this model
callbacks = [
        keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")]

history = model.fit(
        train_dataset,
        epochs=100,
        validation_data=validation_dataset,
        callbacks=callbacks)
# Out:
# Epoch 1/100
# 63/63 [==============================] - 15s 225ms/step - loss: 0.4412 - accuracy: 0.8030 - val_loss: 0.4858 - val_accuracy: 0.7650
# Epoch 2/100
# 63/63 [==============================] - 14s 214ms/step - loss: 0.4553 - accuracy: 0.7965 - val_loss: 0.4913 - val_accuracy: 0.7520
# Epoch 3/100
# 63/63 [==============================] - 15s 239ms/step - loss: 0.4368 - accuracy: 0.8005 - val_loss: 0.5141 - val_accuracy: 0.7750
# Epoch 4/100
# 63/63 [==============================] - 15s 228ms/step - loss: 0.3959 - accuracy: 0.8195 - val_loss: 0.6220 - val_accuracy: 0.7240
# Epoch 5/100
# 63/63 [==============================] - 14s 222ms/step - loss: 0.4454 - accuracy: 0.8065 - val_loss: 0.6107 - val_accuracy: 0.7480
# Epoch 6/100
# 63/63 [==============================] - 13s 207ms/step - loss: 0.4045 - accuracy: 0.8260 - val_loss: 0.5632 - val_accuracy: 0.7760
# Epoch 7/100
# 63/63 [==============================] - 17s 264ms/step - loss: 0.4049 - accuracy: 0.8175 - val_loss: 0.4867 - val_accuracy: 0.7720
# Epoch 8/100
# 63/63 [==============================] - 17s 270ms/step - loss: 0.3750 - accuracy: 0.8245 - val_loss: 0.5024 - val_accuracy: 0.7730
# Epoch 9/100
# 63/63 [==============================] - 15s 227ms/step - loss: 0.3683 - accuracy: 0.8355 - val_loss: 0.4981 - val_accuracy: 0.7720
# Epoch 10/100
# 63/63 [==============================] - 16s 249ms/step - loss: 0.3647 - accuracy: 0.8385 - val_loss: 0.5007 - val_accuracy: 0.7710
# Epoch 11/100
# 63/63 [==============================] - 18s 277ms/step - loss: 0.3557 - accuracy: 0.8525 - val_loss: 0.5307 - val_accuracy: 0.7740
# Epoch 12/100
# 63/63 [==============================] - 17s 274ms/step - loss: 0.3385 - accuracy: 0.8455 - val_loss: 0.5515 - val_accuracy: 0.7760
# Epoch 13/100
# 63/63 [==============================] - 16s 252ms/step - loss: 0.3424 - accuracy: 0.8490 - val_loss: 0.5695 - val_accuracy: 0.7840
# Epoch 14/100
# 63/63 [==============================] - 20s 303ms/step - loss: 0.3300 - accuracy: 0.8630 - val_loss: 0.5588 - val_accuracy: 0.7720
# Epoch 15/100
# 63/63 [==============================] - 19s 303ms/step - loss: 0.3039 - accuracy: 0.8695 - val_loss: 0.6939 - val_accuracy: 0.7450
# Epoch 16/100
# 63/63 [==============================] - 21s 324ms/step - loss: 0.3208 - accuracy: 0.8620 - val_loss: 0.5494 - val_accuracy: 0.7870
# Epoch 17/100
# 63/63 [==============================] - 17s 265ms/step - loss: 0.2917 - accuracy: 0.8780 - val_loss: 0.6968 - val_accuracy: 0.7490
# Epoch 18/100
# 63/63 [==============================] - 13s 209ms/step - loss: 0.2782 - accuracy: 0.8850 - val_loss: 0.7116 - val_accuracy: 0.7800
# Epoch 19/100
# 63/63 [==============================] - 13s 208ms/step - loss: 0.2898 - accuracy: 0.8750 - val_loss: 0.6936 - val_accuracy: 0.7970
# Epoch 20/100
# 63/63 [==============================] - 13s 206ms/step - loss: 0.2651 - accuracy: 0.8885 - val_loss: 0.9576 - val_accuracy: 0.7210
# Epoch 21/100
# 63/63 [==============================] - 15s 224ms/step - loss: 0.2815 - accuracy: 0.8820 - val_loss: 0.7155 - val_accuracy: 0.7810
# Epoch 22/100
# 63/63 [==============================] - 14s 213ms/step - loss: 0.2635 - accuracy: 0.8910 - val_loss: 0.5651 - val_accuracy: 0.7820
# Epoch 23/100
# 63/63 [==============================] - 13s 206ms/step - loss: 0.2564 - accuracy: 0.8925 - val_loss: 0.6289 - val_accuracy: 0.7770
# Epoch 24/100
# 63/63 [==============================] - 15s 229ms/step - loss: 0.2381 - accuracy: 0.9005 - val_loss: 0.6180 - val_accuracy: 0.7860
# Epoch 25/100
# 63/63 [==============================] - 14s 226ms/step - loss: 0.2536 - accuracy: 0.8960 - val_loss: 0.6987 - val_accuracy: 0.7770
# Epoch 26/100
# 63/63 [==============================] - 14s 211ms/step - loss: 0.2648 - accuracy: 0.8980 - val_loss: 0.5527 - val_accuracy: 0.7810
# Epoch 27/100
# 63/63 [==============================] - 13s 207ms/step - loss: 0.2376 - accuracy: 0.9170 - val_loss: 0.6078 - val_accuracy: 0.8050
# Epoch 28/100
# 63/63 [==============================] - 14s 211ms/step - loss: 0.2274 - accuracy: 0.9070 - val_loss: 0.6014 - val_accuracy: 0.7910
# Epoch 29/100
# 63/63 [==============================] - 13s 210ms/step - loss: 0.2116 - accuracy: 0.9120 - val_loss: 0.7844 - val_accuracy: 0.7720
# Epoch 30/100
# 63/63 [==============================] - 13s 208ms/step - loss: 0.2034 - accuracy: 0.9255 - val_loss: 0.7491 - val_accuracy: 0.7550
# Epoch 31/100
# 63/63 [==============================] - 14s 214ms/step - loss: 0.2289 - accuracy: 0.9105 - val_loss: 0.6530 - val_accuracy: 0.7890
# Epoch 32/100
# 63/63 [==============================] - 14s 211ms/step - loss: 0.2017 - accuracy: 0.9155 - val_loss: 0.6768 - val_accuracy: 0.7870
# Epoch 33/100
# 63/63 [==============================] - 15s 234ms/step - loss: 0.2101 - accuracy: 0.9170 - val_loss: 0.7521 - val_accuracy: 0.7710
# Epoch 34/100
# 63/63 [==============================] - 14s 212ms/step - loss: 0.2140 - accuracy: 0.9135 - val_loss: 0.5690 - val_accuracy: 0.7840
# Epoch 35/100
# 63/63 [==============================] - 13s 209ms/step - loss: 0.1860 - accuracy: 0.9235 - val_loss: 0.8479 - val_accuracy: 0.7500
# Epoch 36/100
# 63/63 [==============================] - 13s 207ms/step - loss: 0.1776 - accuracy: 0.9340 - val_loss: 0.6633 - val_accuracy: 0.8160
# Epoch 37/100
# 63/63 [==============================] - 13s 211ms/step - loss: 0.1806 - accuracy: 0.9290 - val_loss: 0.7013 - val_accuracy: 0.8030
# Epoch 38/100
# 63/63 [==============================] - 13s 208ms/step - loss: 0.1857 - accuracy: 0.9295 - val_loss: 0.9079 - val_accuracy: 0.7480
# Epoch 39/100
# 63/63 [==============================] - 13s 208ms/step - loss: 0.1718 - accuracy: 0.9300 - val_loss: 0.6609 - val_accuracy: 0.7950
# Epoch 40/100
# 63/63 [==============================] - 13s 209ms/step - loss: 0.1884 - accuracy: 0.9285 - val_loss: 0.7453 - val_accuracy: 0.8050
# Epoch 41/100
# 63/63 [==============================] - 13s 209ms/step - loss: 0.1359 - accuracy: 0.9460 - val_loss: 0.6609 - val_accuracy: 0.8220
# Epoch 42/100
# 63/63 [==============================] - 13s 210ms/step - loss: 0.1405 - accuracy: 0.9495 - val_loss: 0.8032 - val_accuracy: 0.7960
# Epoch 43/100
# 63/63 [==============================] - 14s 213ms/step - loss: 0.2029 - accuracy: 0.9280 - val_loss: 0.8762 - val_accuracy: 0.7800
# Epoch 44/100
# 63/63 [==============================] - 13s 209ms/step - loss: 0.1656 - accuracy: 0.9420 - val_loss: 0.7125 - val_accuracy: 0.8090
# Epoch 45/100
# 63/63 [==============================] - 14s 215ms/step - loss: 0.1556 - accuracy: 0.9470 - val_loss: 0.7046 - val_accuracy: 0.8110
# Epoch 46/100
# 63/63 [==============================] - 13s 208ms/step - loss: 0.1696 - accuracy: 0.9440 - val_loss: 0.6792 - val_accuracy: 0.8150
# Epoch 47/100
# 63/63 [==============================] - 13s 210ms/step - loss: 0.1652 - accuracy: 0.9475 - val_loss: 0.6880 - val_accuracy: 0.8250
# Epoch 48/100
# 63/63 [==============================] - 13s 208ms/step - loss: 0.1413 - accuracy: 0.9455 - val_loss: 0.7888 - val_accuracy: 0.7920
# Epoch 49/100
# 63/63 [==============================] - 14s 212ms/step - loss: 0.1440 - accuracy: 0.9485 - val_loss: 0.6926 - val_accuracy: 0.7980
# Epoch 50/100
# 63/63 [==============================] - 14s 213ms/step - loss: 0.1341 - accuracy: 0.9520 - val_loss: 0.8280 - val_accuracy: 0.7670
# Epoch 51/100
# 63/63 [==============================] - 13s 210ms/step - loss: 0.1383 - accuracy: 0.9485 - val_loss: 0.8283 - val_accuracy: 0.8140
# Epoch 52/100
# 63/63 [==============================] - 13s 209ms/step - loss: 0.1307 - accuracy: 0.9535 - val_loss: 0.8852 - val_accuracy: 0.7940
# Epoch 53/100
# 63/63 [==============================] - 13s 207ms/step - loss: 0.1290 - accuracy: 0.9495 - val_loss: 0.9531 - val_accuracy: 0.8010
# Epoch 54/100
# 63/63 [==============================] - 14s 216ms/step - loss: 0.1517 - accuracy: 0.9535 - val_loss: 0.8724 - val_accuracy: 0.8050
# Epoch 55/100
# 63/63 [==============================] - 13s 210ms/step - loss: 0.1125 - accuracy: 0.9605 - val_loss: 0.9621 - val_accuracy: 0.7980
# Epoch 56/100
# 63/63 [==============================] - 13s 207ms/step - loss: 0.1410 - accuracy: 0.9510 - val_loss: 0.7934 - val_accuracy: 0.8100
# Epoch 57/100
# 63/63 [==============================] - 13s 207ms/step - loss: 0.1384 - accuracy: 0.9500 - val_loss: 0.9547 - val_accuracy: 0.7910
# Epoch 58/100
# 63/63 [==============================] - 14s 211ms/step - loss: 0.1495 - accuracy: 0.9470 - val_loss: 0.7709 - val_accuracy: 0.8200
# Epoch 59/100
# 63/63 [==============================] - 14s 211ms/step - loss: 0.1348 - accuracy: 0.9555 - val_loss: 1.0052 - val_accuracy: 0.8060
# Epoch 60/100
# 63/63 [==============================] - 13s 210ms/step - loss: 0.1232 - accuracy: 0.9550 - val_loss: 0.9051 - val_accuracy: 0.7970
# Epoch 61/100
# 63/63 [==============================] - 13s 211ms/step - loss: 0.0999 - accuracy: 0.9660 - val_loss: 0.8574 - val_accuracy: 0.8120
# Epoch 62/100
# 63/63 [==============================] - 13s 208ms/step - loss: 0.1471 - accuracy: 0.9465 - val_loss: 0.8009 - val_accuracy: 0.8020
# Epoch 63/100
# 63/63 [==============================] - 13s 209ms/step - loss: 0.1285 - accuracy: 0.9585 - val_loss: 1.0023 - val_accuracy: 0.7920
# Epoch 64/100
# 63/63 [==============================] - 13s 206ms/step - loss: 0.1220 - accuracy: 0.9610 - val_loss: 1.0386 - val_accuracy: 0.8040
# Epoch 65/100
# 63/63 [==============================] - 13s 207ms/step - loss: 0.1159 - accuracy: 0.9610 - val_loss: 0.7779 - val_accuracy: 0.8030
# Epoch 66/100
# 63/63 [==============================] - 13s 208ms/step - loss: 0.1255 - accuracy: 0.9535 - val_loss: 0.9059 - val_accuracy: 0.8060
# Epoch 67/100
# 63/63 [==============================] - 14s 213ms/step - loss: 0.1234 - accuracy: 0.9575 - val_loss: 0.9675 - val_accuracy: 0.8060
# Epoch 68/100
# 63/63 [==============================] - 13s 207ms/step - loss: 0.1108 - accuracy: 0.9625 - val_loss: 1.1957 - val_accuracy: 0.8050
# Epoch 69/100
# 63/63 [==============================] - 13s 209ms/step - loss: 0.1099 - accuracy: 0.9570 - val_loss: 0.9220 - val_accuracy: 0.8080
# Epoch 70/100
# 63/63 [==============================] - 13s 207ms/step - loss: 0.1222 - accuracy: 0.9615 - val_loss: 0.9917 - val_accuracy: 0.8030
# Epoch 71/100
# 63/63 [==============================] - 13s 208ms/step - loss: 0.1193 - accuracy: 0.9630 - val_loss: 1.1140 - val_accuracy: 0.8070
# Epoch 72/100
# 63/63 [==============================] - 13s 208ms/step - loss: 0.1349 - accuracy: 0.9590 - val_loss: 1.1620 - val_accuracy: 0.8030
# Epoch 73/100
# 63/63 [==============================] - 13s 209ms/step - loss: 0.1255 - accuracy: 0.9625 - val_loss: 0.8989 - val_accuracy: 0.8020
# Epoch 74/100
# 63/63 [==============================] - 13s 207ms/step - loss: 0.1403 - accuracy: 0.9575 - val_loss: 1.0010 - val_accuracy: 0.7900
# Epoch 75/100
# 63/63 [==============================] - 13s 209ms/step - loss: 0.1157 - accuracy: 0.9620 - val_loss: 1.2010 - val_accuracy: 0.8150
# Epoch 76/100
# 63/63 [==============================] - 13s 205ms/step - loss: 0.1316 - accuracy: 0.9600 - val_loss: 1.1197 - val_accuracy: 0.7880
# Epoch 77/100
# 63/63 [==============================] - 13s 207ms/step - loss: 0.1389 - accuracy: 0.9600 - val_loss: 0.9134 - val_accuracy: 0.7980
# Epoch 78/100
# 63/63 [==============================] - 13s 207ms/step - loss: 0.1213 - accuracy: 0.9635 - val_loss: 0.9627 - val_accuracy: 0.8350
# Epoch 79/100
# 63/63 [==============================] - 14s 211ms/step - loss: 0.1378 - accuracy: 0.9600 - val_loss: 1.1281 - val_accuracy: 0.7840
# Epoch 80/100
# 63/63 [==============================] - 13s 206ms/step - loss: 0.1227 - accuracy: 0.9525 - val_loss: 1.0340 - val_accuracy: 0.8140
# Epoch 81/100
# 63/63 [==============================] - 13s 206ms/step - loss: 0.1173 - accuracy: 0.9645 - val_loss: 1.3508 - val_accuracy: 0.7690
# Epoch 82/100
# 63/63 [==============================] - 13s 207ms/step - loss: 0.1139 - accuracy: 0.9550 - val_loss: 0.9745 - val_accuracy: 0.8150
# Epoch 83/100
# 63/63 [==============================] - 14s 211ms/step - loss: 0.1193 - accuracy: 0.9595 - val_loss: 1.1274 - val_accuracy: 0.8020
# Epoch 84/100
# 63/63 [==============================] - 13s 204ms/step - loss: 0.1175 - accuracy: 0.9630 - val_loss: 1.0966 - val_accuracy: 0.8110
# Epoch 85/100
# 63/63 [==============================] - 13s 207ms/step - loss: 0.1454 - accuracy: 0.9600 - val_loss: 1.3226 - val_accuracy: 0.7860
# Epoch 86/100
# 63/63 [==============================] - 13s 207ms/step - loss: 0.1082 - accuracy: 0.9685 - val_loss: 1.4862 - val_accuracy: 0.7980
# Epoch 87/100
# 63/63 [==============================] - 13s 207ms/step - loss: 0.1094 - accuracy: 0.9610 - val_loss: 1.0626 - val_accuracy: 0.7950
# Epoch 88/100
# 63/63 [==============================] - 13s 206ms/step - loss: 0.1143 - accuracy: 0.9650 - val_loss: 0.9213 - val_accuracy: 0.8290
# Epoch 89/100
# 63/63 [==============================] - 13s 205ms/step - loss: 0.1339 - accuracy: 0.9615 - val_loss: 1.0465 - val_accuracy: 0.7860
# Epoch 90/100
# 63/63 [==============================] - 13s 208ms/step - loss: 0.1034 - accuracy: 0.9650 - val_loss: 1.0434 - val_accuracy: 0.8200
# Epoch 91/100
# 63/63 [==============================] - 13s 210ms/step - loss: 0.1282 - accuracy: 0.9585 - val_loss: 2.0793 - val_accuracy: 0.8060
# Epoch 92/100
# 63/63 [==============================] - 13s 207ms/step - loss: 0.1359 - accuracy: 0.9645 - val_loss: 1.4949 - val_accuracy: 0.7820
# Epoch 93/100
# 63/63 [==============================] - 13s 206ms/step - loss: 0.1041 - accuracy: 0.9625 - val_loss: 2.1974 - val_accuracy: 0.7780
# Epoch 94/100
# 63/63 [==============================] - 13s 208ms/step - loss: 0.0894 - accuracy: 0.9685 - val_loss: 1.0974 - val_accuracy: 0.8100
# Epoch 95/100
# 63/63 [==============================] - 13s 208ms/step - loss: 0.1305 - accuracy: 0.9645 - val_loss: 0.9309 - val_accuracy: 0.8180
# Epoch 96/100
# 63/63 [==============================] - 13s 206ms/step - loss: 0.0891 - accuracy: 0.9665 - val_loss: 1.0434 - val_accuracy: 0.8150
# Epoch 97/100
# 63/63 [==============================] - 13s 207ms/step - loss: 0.1050 - accuracy: 0.9665 - val_loss: 1.2054 - val_accuracy: 0.8130
# Epoch 98/100
# 63/63 [==============================] - 13s 207ms/step - loss: 0.1398 - accuracy: 0.9590 - val_loss: 1.0995 - val_accuracy: 0.7880
# Epoch 99/100
# 63/63 [==============================] - 21s 330ms/step - loss: 0.1100 - accuracy: 0.9630 - val_loss: 1.1600 - val_accuracy: 0.8280
# Epoch 100/100
# 63/63 [==============================] - 13s 209ms/step - loss: 0.1213 - accuracy: 0.9635 - val_loss: 1.2667 - val_accuracy: 0.7880

# %%
# plotting results
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
# evaluating on test dataset
test_model = keras.models.load_model("convnet_from_scratch_with_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 63/63 [==============================] - 3s 48ms/step - loss: 0.5132 - accuracy: 0.7450
# Test accuracy: 0.745

# %% [markdown]
# # 8.3 Leveraging a pretrained model

# %% [markdown]
# # 8.3.1 Feature extraction with a pretrained model
#
# only use the convolutional base from the pretrained model. Use learnt features from convolutional base as input to our custom classifier

# %%
# instantiate the VGG16 model

conv_base = keras.applications.vgg16.VGG16(
            weights = "imagenet",
            include_top = False,
            input_shape = (180, 180, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 180, 180, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 180, 180, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 90, 90, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 90, 90, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 90, 90, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 45, 45, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 45, 45, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 22, 22, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 22, 22, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 11, 11, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 5, 5, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 2 techniques:
# - run the conv base on data, record output to a numpy array, and use this data as input to a standalone densely connected classifier (doesn't allow data augmentation, cheap to run)
# - extend the conv base by adding dense layers on top and run the whole end to end on data (allows data augmentation, expensive to run)

# %% [markdown]
# ## 8.3.1.1 Fast Feature extraction without data augmentation
#
# Extract features as numpy arrays by calling the `predict` method

# %%
import numpy as np

def get_features_and_labels(dataset):
    all_features = []
    all_labels = []
    for images, labels in dataset:
        preprocessed_images = keras.applications.vgg16.preprocess_input(images)
        features = conv_base.predict(preprocessed_images)
        all_features.append(features)
        all_labels.append(labels)
    return np.concatenate(all_features), np.concatenate(all_labels)

# %%
# getting extracted features
train_features, train_labels = get_features_and_labels(train_dataset)
val_features, val_labels = get_features_and_labels(validation_dataset)
test_features, test_labels = get_features_and_labels(test_dataset)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 1s 809ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step

# %%
train_features.shape
# Out:
# (2000, 5, 5, 512)

# %%
# creating our densely connected classifier
inputs = keras.Input(shape = (5, 5, 512))
x = layers.Flatten()(inputs)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)

model.compile(loss="binary_crossentropy",
             optimizer="rmsprop",
             metrics = ["accuracy"])

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction.keras",
        save_best_only=True,
        monitor="val_loss")
    ]
history = model.fit(
        train_features, train_labels,
        epochs=20,
        validation_data=(val_features, val_labels),
        callbacks=callbacks)
# Out:
# Epoch 1/20
# 63/63 [==============================] - 1s 9ms/step - loss: 15.5965 - accuracy: 0.9280 - val_loss: 2.9867 - val_accuracy: 0.9750
# Epoch 2/20
# 63/63 [==============================] - 0s 6ms/step - loss: 3.6481 - accuracy: 0.9740 - val_loss: 5.0686 - val_accuracy: 0.9620
# Epoch 3/20
# 63/63 [==============================] - 0s 7ms/step - loss: 3.2682 - accuracy: 0.9760 - val_loss: 5.4473 - val_accuracy: 0.9720
# Epoch 4/20
# 63/63 [==============================] - 0s 5ms/step - loss: 1.2916 - accuracy: 0.9880 - val_loss: 4.0373 - val_accuracy: 0.9700
# Epoch 5/20
# 63/63 [==============================] - 0s 6ms/step - loss: 1.0263 - accuracy: 0.9925 - val_loss: 4.1288 - val_accuracy: 0.9700
# Epoch 6/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6167 - accuracy: 0.9945 - val_loss: 4.0651 - val_accuracy: 0.9770
# Epoch 7/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.4741 - accuracy: 0.9955 - val_loss: 5.4239 - val_accuracy: 0.9770
# Epoch 8/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.4515 - accuracy: 0.9955 - val_loss: 3.5728 - val_accuracy: 0.9790
# Epoch 9/20
# 63/63 [==============================] - 0s 5ms/step - loss: 0.3819 - accuracy: 0.9955 - val_loss: 3.9718 - val_accuracy: 0.9740
# Epoch 10/20
# 63/63 [==============================] - 0s 7ms/step - loss: 0.1269 - accuracy: 0.9975 - val_loss: 4.5954 - val_accuracy: 0.9770
# Epoch 11/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0403 - accuracy: 0.9995 - val_loss: 4.9869 - val_accuracy: 0.9760
# Epoch 12/20
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0825 - accuracy: 0.9980 - val_loss: 4.2837 - val_accuracy: 0.9790
# Epoch 13/20
# 63/63 [==============================] - 1s 8ms/step - loss: 0.0275 - accuracy: 0.9990 - val_loss: 4.0526 - val_accuracy: 0.9780
# Epoch 14/20
# 63/63 [==============================] - 0s 8ms/step - loss: 0.1726 - accuracy: 0.9975 - val_loss: 4.1856 - val_accuracy: 0.9780
# Epoch 15/20
# 63/63 [==============================] - 0s 8ms/step - loss: 0.1548 - accuracy: 0.9995 - val_loss: 6.0106 - val_accuracy: 0.9740
# Epoch 16/20
# 63/63 [==============================] - 1s 8ms/step - loss: 0.0193 - accuracy: 0.9995 - val_loss: 5.1331 - val_accuracy: 0.9740
# Epoch 17/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.1417 - accuracy: 0.9995 - val_loss: 6.1475 - val_accuracy: 0.9750
# Epoch 18/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.2123 - accuracy: 0.9975 - val_loss: 5.2270 - val_accuracy: 0.9730
# Epoch 19/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.2291 - accuracy: 0.9975 - val_loss: 6.1844 - val_accuracy: 0.9720
# Epoch 20/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0522 - accuracy: 0.9985 - val_loss: 6.0137 - val_accuracy: 0.9760

# %%
# plotting results
import matplotlib.pyplot as plt
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "bo", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# ## 8.3.1.2 Feature extraction along with data augmentation
# The previous method shows overfitting from the start, because we're using a small dataset with no data augmentation

# %%
# start by instantiating and freezing weights of conv base
conv_base = keras.applications.vgg16.VGG16(
        weights="imagenet",
        include_top=False)

conv_base.trainable = False

# %%
conv_base.trainable = True
print("This is the number of trainable weights before freezing: ", len(conv_base.trainable_weights))
conv_base.trainable = False
print("This is the number of trainable weights after freezing: ", len(conv_base.trainable_weights))
# Out:
# This is the number of trainable weights before freezing:  26
# This is the number of trainable weights after freezing:  0

# %% [markdown]
# ### Create a model that chains together:
# 1. Data augmentation stage
# 2. Frozen convolutional base
# 3. Dense classifier

# %%
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
])

inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = keras.applications.vgg16.preprocess_input(x)
x = conv_base(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)

model = keras.Model(inputs, outputs)
model.compile(loss="binary_crossentropy",
            optimizer="rmsprop",
            metrics=["accuracy"])
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
len(model.trainable_weights)
# 2 for each dense layer (weight and bias)
# Out:
# 4

# %%
callbacks = [
      keras.callbacks.ModelCheckpoint(
      filepath="feature_extraction_with_data_augmentation.keras",
      save_best_only=True,
      monitor="val_loss")
]

history = model.fit(
      train_dataset,
      epochs=50,
      validation_data=validation_dataset,
      callbacks=callbacks)
# Out:
# Epoch 1/50
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 63/63 [==============================] - 22s 272ms/step - loss: 17.3533 - accuracy: 0.8880 - val_loss: 3.8847 - val_accuracy: 0.9750
# Epoch 2/50
# 63/63 [==============================] - 20s 308ms/step - loss: 6.7570 - accuracy: 0.9515 - val_loss: 5.5460 - val_accuracy: 0.9690
# Epoch 3/50
# 63/63 [==============================] - 17s 269ms/step - loss: 4.5668 - accuracy: 0.9655 - val_loss: 6.4039 - val_accuracy: 0.9620
# Epoch 4/50
# 63/63 [==============================] - 17s 268ms/step - loss: 5.3473 - accuracy: 0.9560 - val_loss: 10.0639 - val_accuracy: 0.9580
# Epoch 5/50
# 63/63 [==============================] - 19s 306ms/step - loss: 3.7984 - accuracy: 0.9695 - val_loss: 5.1155 - val_accuracy: 0.9720
# Epoch 6/50
# 63/63 [==============================] - 19s 294ms/step - loss: 2.4920 - accuracy: 0.9765 - val_loss: 8.0645 - val_accuracy: 0.9650
# Epoch 7/50
# 63/63 [==============================] - 20s 314ms/step - loss: 2.8766 - accuracy: 0.9735 - val_loss: 5.4204 - val_accuracy: 0.9740
# Epoch 8/50
# 63/63 [==============================] - 18s 278ms/step - loss: 3.1648 - accuracy: 0.9740 - val_loss: 5.7897 - val_accuracy: 0.9760
# Epoch 9/50
# 63/63 [==============================] - 19s 298ms/step - loss: 1.6402 - accuracy: 0.9865 - val_loss: 4.9111 - val_accuracy: 0.9740
# Epoch 10/50
# 63/63 [==============================] - 20s 309ms/step - loss: 2.6614 - accuracy: 0.9810 - val_loss: 5.1879 - val_accuracy: 0.9750
# Epoch 11/50
# 63/63 [==============================] - 20s 312ms/step - loss: 2.2347 - accuracy: 0.9800 - val_loss: 5.6969 - val_accuracy: 0.9750
# Epoch 12/50
# 63/63 [==============================] - 23s 356ms/step - loss: 1.3963 - accuracy: 0.9840 - val_loss: 7.3103 - val_accuracy: 0.9680
# Epoch 13/50
# 63/63 [==============================] - 23s 360ms/step - loss: 2.3174 - accuracy: 0.9795 - val_loss: 5.6290 - val_accuracy: 0.9770
# Epoch 14/50
# 63/63 [==============================] - 18s 290ms/step - loss: 2.1457 - accuracy: 0.9830 - val_loss: 4.6702 - val_accuracy: 0.9760
# Epoch 15/50
# 63/63 [==============================] - 18s 274ms/step - loss: 1.4365 - accuracy: 0.9860 - val_loss: 4.4846 - val_accuracy: 0.9790
# Epoch 16/50
# 63/63 [==============================] - 18s 273ms/step - loss: 2.1663 - accuracy: 0.9810 - val_loss: 4.9094 - val_accuracy: 0.9740
# Epoch 17/50
# 63/63 [==============================] - 19s 303ms/step - loss: 1.2613 - accuracy: 0.9835 - val_loss: 4.5084 - val_accuracy: 0.9800
# Epoch 18/50
# 63/63 [==============================] - 20s 313ms/step - loss: 1.4945 - accuracy: 0.9840 - val_loss: 4.7309 - val_accuracy: 0.9760
# Epoch 19/50
# 63/63 [==============================] - 24s 369ms/step - loss: 1.3328 - accuracy: 0.9845 - val_loss: 4.7389 - val_accuracy: 0.9750
# Epoch 20/50
# 63/63 [==============================] - 19s 303ms/step - loss: 0.9405 - accuracy: 0.9895 - val_loss: 4.2232 - val_accuracy: 0.9770
# Epoch 21/50
# 63/63 [==============================] - 21s 333ms/step - loss: 0.8809 - accuracy: 0.9900 - val_loss: 4.3336 - val_accuracy: 0.9730
# Epoch 22/50
# 63/63 [==============================] - 22s 354ms/step - loss: 1.1095 - accuracy: 0.9880 - val_loss: 3.6829 - val_accuracy: 0.9810
# Epoch 23/50
# 63/63 [==============================] - 19s 302ms/step - loss: 1.1157 - accuracy: 0.9890 - val_loss: 3.9920 - val_accuracy: 0.9750
# Epoch 24/50
# 63/63 [==============================] - 20s 311ms/step - loss: 1.2490 - accuracy: 0.9855 - val_loss: 3.9492 - val_accuracy: 0.9780
# Epoch 25/50
# 63/63 [==============================] - 18s 284ms/step - loss: 0.6666 - accuracy: 0.9935 - val_loss: 3.7602 - val_accuracy: 0.9750
# Epoch 26/50
# 63/63 [==============================] - 17s 269ms/step - loss: 0.3914 - accuracy: 0.9925 - val_loss: 4.6299 - val_accuracy: 0.9730
# Epoch 27/50
# 63/63 [==============================] - 18s 279ms/step - loss: 0.9312 - accuracy: 0.9895 - val_loss: 4.7870 - val_accuracy: 0.9740
# Epoch 28/50
# 63/63 [==============================] - 22s 345ms/step - loss: 0.3232 - accuracy: 0.9945 - val_loss: 3.1075 - val_accuracy: 0.9770
# Epoch 29/50
# 63/63 [==============================] - 25s 396ms/step - loss: 0.2964 - accuracy: 0.9925 - val_loss: 4.6678 - val_accuracy: 0.9750
# Epoch 30/50
# 63/63 [==============================] - 23s 358ms/step - loss: 1.2101 - accuracy: 0.9855 - val_loss: 4.3344 - val_accuracy: 0.9740
# Epoch 31/50
# 63/63 [==============================] - 26s 410ms/step - loss: 0.6023 - accuracy: 0.9905 - val_loss: 4.6162 - val_accuracy: 0.9730
# Epoch 32/50
# 63/63 [==============================] - 26s 401ms/step - loss: 0.7140 - accuracy: 0.9900 - val_loss: 4.1547 - val_accuracy: 0.9780
# Epoch 33/50
# 63/63 [==============================] - 22s 341ms/step - loss: 0.7362 - accuracy: 0.9895 - val_loss: 4.1493 - val_accuracy: 0.9750
# Epoch 34/50
# 63/63 [==============================] - 25s 401ms/step - loss: 0.6549 - accuracy: 0.9910 - val_loss: 3.8461 - val_accuracy: 0.9770
# Epoch 35/50
# 63/63 [==============================] - 21s 327ms/step - loss: 0.5190 - accuracy: 0.9915 - val_loss: 4.7768 - val_accuracy: 0.9720
# Epoch 36/50
# 63/63 [==============================] - 17s 270ms/step - loss: 0.4841 - accuracy: 0.9930 - val_loss: 3.5418 - val_accuracy: 0.9810
# Epoch 37/50
# 63/63 [==============================] - 18s 285ms/step - loss: 0.5864 - accuracy: 0.9935 - val_loss: 3.7724 - val_accuracy: 0.9800
# Epoch 38/50
# 63/63 [==============================] - 17s 270ms/step - loss: 0.7420 - accuracy: 0.9915 - val_loss: 3.6426 - val_accuracy: 0.9760
# Epoch 39/50
# 63/63 [==============================] - 17s 273ms/step - loss: 0.3652 - accuracy: 0.9930 - val_loss: 4.1482 - val_accuracy: 0.9720
# Epoch 40/50
# 63/63 [==============================] - 18s 275ms/step - loss: 0.5418 - accuracy: 0.9920 - val_loss: 2.8745 - val_accuracy: 0.9780
# Epoch 41/50
# 63/63 [==============================] - 19s 292ms/step - loss: 0.9746 - accuracy: 0.9900 - val_loss: 2.7691 - val_accuracy: 0.9760
# Epoch 42/50
# 63/63 [==============================] - 17s 273ms/step - loss: 0.4692 - accuracy: 0.9915 - val_loss: 3.6896 - val_accuracy: 0.9710
# Epoch 43/50
# 63/63 [==============================] - 17s 274ms/step - loss: 0.1328 - accuracy: 0.9965 - val_loss: 3.1385 - val_accuracy: 0.9730
# Epoch 44/50
# 63/63 [==============================] - 17s 271ms/step - loss: 0.2078 - accuracy: 0.9965 - val_loss: 3.2752 - val_accuracy: 0.9760
# Epoch 45/50
# 63/63 [==============================] - 17s 271ms/step - loss: 0.4941 - accuracy: 0.9930 - val_loss: 3.0481 - val_accuracy: 0.9750
# Epoch 46/50
# 63/63 [==============================] - 20s 308ms/step - loss: 0.1587 - accuracy: 0.9940 - val_loss: 3.1902 - val_accuracy: 0.9710
# Epoch 47/50
# 63/63 [==============================] - 17s 272ms/step - loss: 0.2446 - accuracy: 0.9950 - val_loss: 3.4660 - val_accuracy: 0.9770
# Epoch 48/50
# 63/63 [==============================] - 17s 270ms/step - loss: 0.5471 - accuracy: 0.9930 - val_loss: 4.7379 - val_accuracy: 0.9740
# Epoch 49/50
# 63/63 [==============================] - 17s 271ms/step - loss: 0.4909 - accuracy: 0.9925 - val_loss: 3.5109 - val_accuracy: 0.9750
# Epoch 50/50
# 63/63 [==============================] - 17s 271ms/step - loss: 0.8567 - accuracy: 0.9885 - val_loss: 3.8706 - val_accuracy: 0.9710

# %%
# plotting results
import matplotlib.pyplot as plt
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "bo", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
# evaluating on test set
test_model = keras.models.load_model(
"feature_extraction_with_data_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 63/63 [==============================] - 6s 85ms/step - loss: 4.3684 - accuracy: 0.9700
# Test accuracy: 0.970

# %% [markdown]
# ## 8.3.2 Fine-tuning a pretrained model
#
# Unfreeze a few of the top layers of the frozen model base. Jointly train this and the added classifier.
#
# **NOTE:** Train the classifier beforehand, and then fine tune by unfreezing some layers. If not, the error signal will be too large and all learnt representations will be destryed

# %% [markdown]
# **STEPS FOR FINE TUNING**
# 1. Add our custom classifier on top of an already trained base network
# 2. Freeze the base network
# 3. Train the part we added
# 4. Unfreeze some layers in the base network (Do not unfreeze BatchNormalization layers)
# 5. Jointly train these layers and the added classifier

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# unfreezing last conv block
conv_base.trainable = True
for layer in conv_base.layers[:-4]:
  layer.trainable = False

# %%
# fine tuning the model
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics = ["accuracy"])

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="fine_tuning.keras",
        save_best_only=True,
        monitor="val_loss"
    )
]

history = model.fit(
    train_dataset,
    epochs=30,
    validation_data = validation_dataset,
    callbacks = callbacks
)
# Out:
# Epoch 1/30
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 63/63 [==============================] - 24s 307ms/step - loss: 636.2950 - accuracy: 0.5245 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 2/30
# 63/63 [==============================] - 18s 287ms/step - loss: 0.6934 - accuracy: 0.4955 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 3/30
# 63/63 [==============================] - 21s 325ms/step - loss: 0.6934 - accuracy: 0.4970 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 4/30
# 63/63 [==============================] - 18s 286ms/step - loss: 0.6933 - accuracy: 0.4875 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 5/30
# 63/63 [==============================] - 19s 298ms/step - loss: 0.6934 - accuracy: 0.4915 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 6/30
# 63/63 [==============================] - 21s 327ms/step - loss: 0.6934 - accuracy: 0.4960 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 7/30
# 63/63 [==============================] - 19s 285ms/step - loss: 0.6933 - accuracy: 0.4950 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 8/30
# 63/63 [==============================] - 18s 284ms/step - loss: 0.6936 - accuracy: 0.4805 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 9/30
# 63/63 [==============================] - 18s 289ms/step - loss: 0.6935 - accuracy: 0.4950 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 10/30
# 63/63 [==============================] - 19s 295ms/step - loss: 0.6933 - accuracy: 0.5010 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 11/30
# 63/63 [==============================] - 18s 284ms/step - loss: 0.6935 - accuracy: 0.4960 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 12/30
# 63/63 [==============================] - 19s 303ms/step - loss: 0.6934 - accuracy: 0.4905 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 13/30
# 63/63 [==============================] - 20s 320ms/step - loss: 0.6935 - accuracy: 0.4915 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 14/30
# 63/63 [==============================] - 18s 285ms/step - loss: 0.6931 - accuracy: 0.4950 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 15/30
# 63/63 [==============================] - 18s 285ms/step - loss: 0.6936 - accuracy: 0.4925 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 16/30
# 63/63 [==============================] - 18s 284ms/step - loss: 0.6934 - accuracy: 0.4820 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 17/30
# 63/63 [==============================] - 20s 320ms/step - loss: 0.6934 - accuracy: 0.4895 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 18/30
# 63/63 [==============================] - 18s 286ms/step - loss: 0.6930 - accuracy: 0.5050 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 19/30
# 63/63 [==============================] - 18s 290ms/step - loss: 0.6933 - accuracy: 0.4890 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 20/30
# 63/63 [==============================] - 18s 284ms/step - loss: 0.6934 - accuracy: 0.4880 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 21/30
# 63/63 [==============================] - 18s 286ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 22/30
# 63/63 [==============================] - 19s 292ms/step - loss: 0.6934 - accuracy: 0.4945 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 23/30
# 63/63 [==============================] - 18s 282ms/step - loss: 0.6932 - accuracy: 0.4950 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 24/30
# 63/63 [==============================] - 18s 288ms/step - loss: 0.6934 - accuracy: 0.5005 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 25/30
# 63/63 [==============================] - 19s 299ms/step - loss: 0.6931 - accuracy: 0.5110 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 26/30
# 63/63 [==============================] - 18s 282ms/step - loss: 0.6932 - accuracy: 0.4995 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 27/30
# 63/63 [==============================] - 19s 298ms/step - loss: 0.6937 - accuracy: 0.4815 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 28/30
# 63/63 [==============================] - 18s 281ms/step - loss: 0.6935 - accuracy: 0.4755 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 29/30
# 63/63 [==============================] - 19s 301ms/step - loss: 0.6932 - accuracy: 0.4805 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 30/30
# 63/63 [==============================] - 20s 321ms/step - loss: 0.6931 - accuracy: 0.5125 - val_loss: 0.6931 - val_accuracy: 0.5000

# %%
model = keras.models.load_model("fine_tuning.keras")
test_loss, test_acc = model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 63/63 [==============================] - 6s 85ms/step - loss: 0.6931 - accuracy: 0.5000
# Test accuracy: 0.500
